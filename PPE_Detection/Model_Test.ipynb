# %%
from ultralytics import YOLO

# %%
model = YOLO('full_model_2/augmentation_earlystop_run/weights/best.pt')
results = model.predict(source="Construction Site 1 - Stock Footage Collection [CtLy8PXiL58].mp4", show=False, save=True, conf=0.5)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1260) d:\Coding\Projects 2\NNProjects\NeuralNetworkProjects\PPE_Detection\Construction Site 1 - Stock Footage Collection [CtLy8PXiL58].mp4: 384x640 (no detections), 69.6ms
# video 1/1 (frame 2/1260) d:\Coding\Projects 2\NNProjects\NeuralNetworkProjects\PPE_Detection\Construction Site 1 - Stock Footage Collection [CtLy8PXiL58].mp4: 384x640 (no detections), 7.8ms
# ...
